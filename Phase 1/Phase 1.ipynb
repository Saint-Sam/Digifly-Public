# %% [markdown]
# # Phase 1

# %% [markdown]
# ## Install Dependencies

# %%
# %pip install neuprint-python navis numpy pandas scipy matplotlib networkx scikit-learn ipywidgets plotly trimesh tqdm openpyxl

# %% [markdown]
# ## Version Check

# %%
import platform
print(platform.python_version())

# %% [markdown]
# ## neuPrint Token

# %%
from pathlib import Path
import sys

phase1_dir = Path.cwd()
if not (phase1_dir / "digifly_phase1").exists():
    phase1_dir = phase1_dir / "Phase 1"
if not (phase1_dir / "digifly_phase1").exists():
    phase1_dir = Path(__file__).resolve().parent if "__file__" in globals() else Path.cwd()

phase1_dir = phase1_dir.resolve()
if str(phase1_dir) in sys.path:
    sys.path.remove(str(phase1_dir))
sys.path.insert(0, str(phase1_dir))

for module_name in list(sys.modules):
    if module_name == "digifly_phase1" or module_name.startswith("digifly_phase1."):
        del sys.modules[module_name]

from digifly_phase1.token_store import ensure_neuprint_token, save_neuprint_token, token_file_path

print(f"Local token file: {token_file_path()}")
_ = ensure_neuprint_token()

# %% [markdown]
# ## Launch Phase 1 Menu

# %%
from pathlib import Path
import sys

phase1_dir = Path.cwd()
if not (phase1_dir / "digifly_phase1").exists():
    phase1_dir = phase1_dir / "Phase 1"
if not (phase1_dir / "digifly_phase1").exists():
    phase1_dir = Path(__file__).resolve().parent if "__file__" in globals() else Path.cwd()

phase1_dir = phase1_dir.resolve()
if str(phase1_dir) in sys.path:
    sys.path.remove(str(phase1_dir))
sys.path.insert(0, str(phase1_dir))

for module_name in list(sys.modules):
    if module_name == "digifly_phase1" or module_name.startswith("digifly_phase1."):
        del sys.modules[module_name]

from digifly_phase1.menu import main_menu

main_menu()
